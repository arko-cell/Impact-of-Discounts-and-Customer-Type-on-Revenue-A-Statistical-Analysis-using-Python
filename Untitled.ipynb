# %%
import numpy as np
import pandas as pd
import os
import matplotlib as plt
import seaborn as sns
import statistics

# %%
data_path = "C:/Users/ASUS/Documents/Project on marketing"

# %%
customers = pd.read_csv(
    os.path.join(data_path, "olist_customers_dataset.csv"),
    usecols=["customer_id", "customer_unique_id"]
)

orders = pd.read_csv(
    os.path.join(data_path, "olist_orders_dataset.csv"),
    usecols=["order_id", "customer_id", "order_purchase_timestamp", "order_status"]
)

payments = pd.read_csv(
    os.path.join(data_path, "olist_order_payments_dataset.csv"),
    usecols=["order_id", "payment_value"]
)

order_items = pd.read_csv(
    os.path.join(data_path, "olist_order_items_dataset.csv"),
    usecols=["order_id", "price", "freight_value"]
)

# %%
df = pd.merge(
    orders,
    customers,
    on="customer_id",
    how="inner")

df = pd.merge(
    df,
    payments,
    on="order_id",
    how="inner")

df = pd.merge(
    df,
    order_items,
    on="order_id",
    how="inner")

# %%
df["order_purchase_timestamp"] = pd.to_datetime(df["order_purchase_timestamp"])

# %%
final_df = df.groupby(
    ["customer_unique_id", "order_id", "order_purchase_timestamp"],
    as_index=False
).agg({
    "payment_value": "sum",
    "price": "sum",
    "freight_value": "sum"
})

# %%
final_df.head(5)
# Out:
#                  customer_unique_id                          order_id  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2  e22acc9c116caa3f2b7121bbb380d08e
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  3594e05a005ac4d06a72673270ef9ec9
# 2  0000f46a3911fa3c0805444483337064  b33ec3b699337181488304f362a6b734
# 3  0000f6ccb0745a6a4b88665a16c9f078  41272756ecddd9a9ed0180413cc22fb6
# 4  0004aac84e0df4da2b147fca70cf8255  d957021f1127559cd947b62533f484f7
#
#   order_purchase_timestamp  payment_value   price  freight_value
# 0      2018-05-10 10:56:27         141.90  129.90          12.00
# 1      2018-05-07 11:11:27          27.19   18.90           8.29
# 2      2017-03-10 21:05:03          86.22   69.00          17.22
# 3      2017-10-12 20:29:41          43.62   25.99          17.63
# 4      2017-11-14 19:45:42         196.89  180.00          16.89

# %%
final_df["revenue"] = final_df["payment_value"]-final_df["price"]

# %%
final_df.head(5)
# Out:
#                  customer_unique_id                          order_id  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2  e22acc9c116caa3f2b7121bbb380d08e
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  3594e05a005ac4d06a72673270ef9ec9
# 2  0000f46a3911fa3c0805444483337064  b33ec3b699337181488304f362a6b734
# 3  0000f6ccb0745a6a4b88665a16c9f078  41272756ecddd9a9ed0180413cc22fb6
# 4  0004aac84e0df4da2b147fca70cf8255  d957021f1127559cd947b62533f484f7
#
#   order_purchase_timestamp  payment_value   price  freight_value  revenue
# 0      2018-05-10 10:56:27         141.90  129.90          12.00    12.00
# 1      2018-05-07 11:11:27          27.19   18.90           8.29     8.29
# 2      2017-03-10 21:05:03          86.22   69.00          17.22    17.22
# 3      2017-10-12 20:29:41          43.62   25.99          17.63    17.63
# 4      2017-11-14 19:45:42         196.89  180.00          16.89    16.89

# %%
final_df.describe()
# Out:
#             order_purchase_timestamp  payment_value         price  \
# count                          98665   98665.000000  98665.000000
# mean   2017-12-31 22:12:16.050483968     205.829166    144.013737
# min              2016-09-04 21:15:19       9.590000      0.850000
# 25%              2017-09-12 23:38:32      62.700000     47.490000
# 50%              2018-01-19 18:06:15     109.680000     89.100000
# 75%              2018-05-04 20:06:46     195.910000    154.000000
# max              2018-09-03 09:06:57  109312.640000  13440.000000
# std                              NaN     620.729403    241.170071
#
#        freight_value       revenue
# count    98665.00000  98665.000000
# mean        23.89326     61.815430
# min          0.00000 -10925.960000
# 25%         14.05000     13.470000
# 50%         17.57000     17.070000
# 75%         25.54000     25.330000
# max       1897.76000  95872.640000
# std         26.35836    521.898024

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98665 entries, 0 to 98664
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_unique_id        98665 non-null  object
#  1   order_id                  98665 non-null  object
#  2   order_purchase_timestamp  98665 non-null  datetime64[ns]
#  3   payment_value             98665 non-null  float64
#  4   price                     98665 non-null  float64
#  5   freight_value             98665 non-null  float64
#  6   revenue                   98665 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 5.3+ MB

# %% [markdown]
# ### Should the company prioritize customer retention over customer acquisition in its marketing strategy?

# %%
customer_summary = final_df.groupby("customer_unique_id").agg(
    total_orders=("order_id", "nunique"),
    total_revenue=("revenue", "sum"),
    avg_order_value=("payment_value", "mean")
).reset_index()

# %%
customer_summary.head(4)
# Out:
#                  customer_unique_id  total_orders  total_revenue  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2             1          12.00
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f             1           8.29
# 2  0000f46a3911fa3c0805444483337064             1          17.22
# 3  0000f6ccb0745a6a4b88665a16c9f078             1          17.63
#
#    avg_order_value
# 0           141.90
# 1            27.19
# 2            86.22
# 3            43.62

# %%
customer_summary["customer_type"] = customer_summary["total_orders"].apply(
    lambda x: "Repeat" if x > 1 else "One-Time"
)

# %%
customer_summary.head(4)
# Out:
#                  customer_unique_id  total_orders  total_revenue  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2             1          12.00
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f             1           8.29
# 2  0000f46a3911fa3c0805444483337064             1          17.22
# 3  0000f6ccb0745a6a4b88665a16c9f078             1          17.63
#
#    avg_order_value customer_type
# 0           141.90      One-Time
# 1            27.19      One-Time
# 2            86.22      One-Time
# 3            43.62      One-Time

# %%
customer_summary.groupby("customer_type")["total_revenue"].describe()
# Out:
#                  count        mean         std       min    25%    50%    75%  \
# customer_type
# One-Time       92506.0   60.300512  523.486243 -10925.96  13.47  17.09  25.25
# Repeat          2913.0  178.805434  884.070964  -4490.03  28.64  37.31  92.32
#
#                     max
# customer_type
# One-Time       95872.64
# Repeat         23855.46

# %%
sns.boxplot(customer_summary['total_revenue'])
# Out:
# <Axes: ylabel='total_revenue'>

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

stats.probplot(customer_summary['total_revenue'], plot=plt)
plt.show()

# %%
from scipy.stats import skew, kurtosis

skewness = skew(customer_summary['total_revenue'])
kurt = kurtosis(customer_summary['total_revenue'])

skewness, kurt
# Out:
# (np.float64(80.72320262785983), np.float64(11750.833381999795))

# %%
sns.histplot(customer_summary['total_revenue'].sample(5000), kde = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 2
#       1 sns.histplot(customer_summary['total_revenue'].sample(5000), kde = True)
# ----> 2 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
from scipy.stats import ttest_ind

repeat_rev = customer_summary[
    customer_summary["customer_type"] == "Repeat"
]["total_revenue"]

one_time_rev = customer_summary[
    customer_summary["customer_type"] == "One-Time"
]["total_revenue"]

ttest_ind(repeat_rev, one_time_rev, equal_var=False)
# Out:
# TtestResult(statistic=np.float64(7.195071772083964), pvalue=np.float64(7.865516396136114e-13), df=np.float64(2976.6461149139336))

# %%
alpha = 0.05
p_value = 7.865516396136114e-13
if p_value < alpha:
    print ("Reject null hypothesis")
else:
    print("Accept null Hypothesis")
# Out:
# Reject null hypothesis

# %%
import numpy as np
from scipy.stats import sem, t

diff_mean = repeat_rev.mean() - one_time_rev.mean()

se = np.sqrt(sem(repeat_rev)**2 + sem(one_time_rev)**2)
ci = t.interval(0.95,
    df=len(repeat_rev)+len(one_time_rev)-2,
    loc=diff_mean,
    scale=se
               )

ci
# Out:
# (np.float64(86.22333675338731), np.float64(150.78650826586008))

# %% [markdown]
# Statistical testing confirms that repeat customers generate significantly higher revenue than one-time buyers (p < 0.05). The 95% confidence interval indicates a substantial profit difference. Therefore, reallocating marketing budget toward customer retention programs is statistically justified.

# %% [markdown]
# ### Do discounted orders generate significantly different revenue compared to non-discounted orders?

# %%
final_df["discount_applied"] = final_df["payment_value"] < final_df["price"]
final_df.head(10)
# Out:
#                  customer_unique_id                          order_id  \
# 0  0000366f3b9a7992bf8c76cfdf3221e2  e22acc9c116caa3f2b7121bbb380d08e
# 1  0000b849f77a49e4a4ce2b2a4ca5be3f  3594e05a005ac4d06a72673270ef9ec9
# 2  0000f46a3911fa3c0805444483337064  b33ec3b699337181488304f362a6b734
# 3  0000f6ccb0745a6a4b88665a16c9f078  41272756ecddd9a9ed0180413cc22fb6
# 4  0004aac84e0df4da2b147fca70cf8255  d957021f1127559cd947b62533f484f7
# 5  0004bd2a26a76fe21f786e4fbd80607f  3e470077b690ea3e3d501cffb5e0c499
# 6  00050ab1314c0e55a6ca13cf7181fecf  d0028facea13f508e880202d7097a5a1
# 7  00053a61a98854899e70ed204dd4bafe  44e608f2db00c74a1fe329de44416a4e
# 8  0005e1862207bf6ccc02e4228effd9a0  ae76bef74b97bcb0b3e355e60d9a6f9c
# 9  0005ef4cd20d2893f0d9fbd94d3c0d97  01b330808c5819a6a3cb79b72f0b8288
#
#   order_purchase_timestamp  payment_value   price  freight_value  revenue  \
# 0      2018-05-10 10:56:27         141.90  129.90          12.00    12.00
# 1      2018-05-07 11:11:27          27.19   18.90           8.29     8.29
# 2      2017-03-10 21:05:03          86.22   69.00          17.22    17.22
# 3      2017-10-12 20:29:41          43.62   25.99          17.63    17.63
# 4      2017-11-14 19:45:42         196.89  180.00          16.89    16.89
# 5      2018-04-05 19:33:16         166.98  154.00          12.98    12.98
# 6      2018-04-20 12:57:23          35.38   27.99           7.39     7.39
# 7      2018-02-28 11:15:41         838.36  382.00          37.18   456.36
# 8      2017-03-04 23:32:12         150.12  135.00          15.12    15.12
# 9      2018-03-12 15:22:12         129.76  104.90          24.86    24.86
#
#    discount_applied
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# 5             False
# 6             False
# 7             False
# 8             False
# 9             False

# %%
final_df["discount_applied"].info
# Out:
# <bound method Series.info of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 98660    False
# 98661    False
# 98662    False
# 98663    False
# 98664    False
# Name: discount_applied, Length: 98665, dtype: bool>

# %%
final_df["discount_applied"].value_counts()
# Out:
# discount_applied
# False    96039
# True      2626
# Name: count, dtype: int64

# %%
final_df.groupby("discount_applied")["revenue"].describe()
# Out:
#                     count        mean         std       min       25%    50%  \
# discount_applied
# False             96039.0   68.729714  519.933988      0.00   13.8600  17.43
# True               2626.0 -191.056211  530.684168 -10925.96 -164.6925 -74.86
#
#                       75%       max
# discount_applied
# False             25.6700  95872.64
# True             -34.0025     -0.01

# %% [markdown]
# Discounted orders show lower average revenue compared to non-discounted orders

# %%
rev_discount = final_df[final_df["discount_applied"]]["revenue"]
rev_no_discount = final_df[~final_df["discount_applied"]]["revenue"]

t_stat, p_value = ttest_ind(
    rev_discount,
    rev_no_discount,
    equal_var=False
)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: -24.76287151882837
# p-value: 1.9443912750795405e-122

# %%
alpha = 0.05

if p_value < alpha:
    print("Discount has a statistically significant impact on revenue")
else:
    print("No statistically significant impact of discount on revenue")
# Out:
# Discount has a statistically significant impact on revenue

# %%
import numpy as np
from scipy.stats import sem, t

mean_diff = rev_no_discount.mean() - rev_discount.mean()

se = np.sqrt(sem(rev_no_discount)**2 + sem(rev_discount)**2)

ci = t.interval(
    0.95,
    df=len(rev_no_discount)+len(rev_discount)-2,
    loc=mean_diff,
    scale=se
)

ci
# Out:
# (np.float64(239.22379799101736), np.float64(280.34805146771873))

# %% [markdown]
# We are 95% confident that non-discounted orders generate more revenue than discounted orders.
